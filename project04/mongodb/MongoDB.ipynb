# %% [markdown]
# # MongoDB Veritabanına Bağlanma & Sorgulama

# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb+srv://<username>:<password>@mycluster.3u0gdjt.mongodb.net/?retryWrites=true&w=majority")
client.test
# Out:
# Database(MongoClient(host=['ac-7h7obnn-shard-00-00.3u0gdjt.mongodb.net:27017', 'ac-7h7obnn-shard-00-02.3u0gdjt.mongodb.net:27017', 'ac-7h7obnn-shard-00-01.3u0gdjt.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-mfzh2e-shard-0', tls=True), 'test')

# %% [markdown]
# >**NOT:** `MongoClient` tanımlaması yaparken, MongoDB Atlas'dan aldığınız connection stringde `<username>` yazan yere tanımladığınız kullanıcı adını, `<password>` yazan yere ise belirlediğiniz parolayı girmeniz gerekiyor.

# %%
db = client.sample_training

# %%
db.list_collection_names()
# Out:
# ['grades', 'zips', 'posts', 'companies', 'routes', 'trips', 'inspections']

# %%
collection = db.get_collection('trips')
collection
# Out:
# Collection(Database(MongoClient(host=['ac-7h7obnn-shard-00-00.3u0gdjt.mongodb.net:27017', 'ac-7h7obnn-shard-00-02.3u0gdjt.mongodb.net:27017', 'ac-7h7obnn-shard-00-01.3u0gdjt.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-mfzh2e-shard-0', tls=True), 'sample_training'), 'trips')

# %%
df = pd.DataFrame(list(collection.find()))
df
# Out:
#                            _id  tripduration  start station id  \
# 0     572bb8222b288919b68abf5a           379               476
# 1     572bb8222b288919b68abf5b           889               268
# 2     572bb8222b288919b68abf5c           589               489
# 3     572bb8222b288919b68abf5d           923               268
# 4     572bb8222b288919b68abf5e           332              3104
# ...                        ...           ...               ...
# 9995  572bb8232b288919b68b1c44           566               442
# 9996  572bb8232b288919b68b1c48           552               438
# 9997  572bb8232b288919b68b1c4b           181              3142
# 9998  572bb8232b288919b68b1c4c           340               537
# 9999  572bb8232b288919b68b1c50          2143               474
#
#            start station name  end station id            end station name  \
# 0             E 31 St & 3 Ave             498          Broadway & W 32 St
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     10000 non-null  object
#  1   tripduration            10000 non-null  int64
#  2   start station id        10000 non-null  int64
#  3   start station name      10000 non-null  object
#  4   end station id          10000 non-null  int64
#  5   end station name        10000 non-null  object
#  6   bikeid                  10000 non-null  int64
#  7   usertype                10000 non-null  object
#  8   birth year              10000 non-null  object
#  9   start station location  10000 non-null  object
#  10  end station location    10000 non-null  object
#  11  start time              10000 non-null  datetime64[ns]
#  12  stop time               10000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(4), object(7)
# ...

# %%
pd.DataFrame(list(collection.find({"usertype":"Customer"})))
# Out:
#                            _id  tripduration  start station id  \
# 0     572bb8222b288919b68abf6d           858               532
# 1     572bb8222b288919b68abf6f           839               532
# 2     572bb8222b288919b68abf70           110               439
# 3     572bb8222b288919b68abf74          2023              3143
# 4     572bb8222b288919b68abf76          1236              3231
# ...                        ...           ...               ...
# 1984  572bb8232b288919b68b1bf3          1121               532
# 1985  572bb8232b288919b68b1c18          1543               285
# 1986  572bb8232b288919b68b1c27          1319              3235
# 1987  572bb8232b288919b68b1c40          3459               281
# 1988  572bb8232b288919b68b1c50          2143               474
#
#                      start station name  end station id  \
# 0                       S 5 Pl & S 4 St             401
# 1                       S 5 Pl & S 4 St             401
# ...

# %% [markdown]
# >**NOT:** Collection tanımlamasını yaptıktan sonra `TAB`'e basarak kullanılabilecek tüm fonksiyonları görüntüleyebilirsiniz.
