# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd
import re
import numpy as np
import time

# %%
def getAndParseURL(url):
    result = requests.get(url, headers={"User-Agent":"Chrome/103.0.0.0"}) # Safari/537.36. Mozilla/5.0
    soup = bts(result.text, "html.parser")
    return soup

# %%
pages = ["https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98"]
for page in range(2,101):
    pages.append("https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa="+str(page))
print(pages[:10])
# Out:
# ['https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=2', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=3', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=4', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=5', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=6', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=7', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=8', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=9', 'https://www.hepsiburada.com/laptop-notebook-dizustu-bilgisayarlar-c-98?sayfa=10']

# %%
len(pages)
# Out:
# 100

# %%
products = []
for page in pages:
    html = getAndParseURL(page)
    for product in html.findAll("li",{"class":"productListContent-item"}):
        products.append("https://www.hepsiburada.com" + product.a.get("href"))
print(products[:25])
# Out:
# ['https://www.hepsiburada.com/lenovo-v14-itl-gen2-intel-core-i5-1135g7-8gb-512gb-ssd-windows-10-home-14-fhd-tasinabilir-bilgisayar-82ka0027tx-p-HBCV00000QK2IA', 'https://www.hepsiburada.com/lenovo-ideapad-intel-celeron-n4020-4gb-128gb-ssd-freedos-14-hd-tasinabilir-bilgisayar-81vu006stx-p-HBV00001658DA', 'https://www.hepsiburada.com/hp-probook-440-g8-intel-core-i5-1135g7-8gb-512gb-ssd-windows-10-pro-14-fhd-tasinabilir-bilgisayar-2x7r2ea-p-HBCV000012L1LM', 'https://www.hepsiburada.com/lenovo-ideapad-l3-intel-core-i5-1135g7-12gb-2tb-ssd-windows-10-home-15-6-fhd-tasinabilir-bilgisayar-82hl009ktx18-p-HBCV00002CTEX9', 'https://www.hepsiburada.com/casper-excalibur-g770-1030-8ph0t-intel-core-i5-10300h-8gb-250gb-ssd-gtx1650-windows-11-home-15-6-fhd-tasinabilir-bilgisayar-p-HBCV000018RK9C', 'https://www.hepsiburada.com/lenovo-v14-g2-itl-intel-core-i5-1135g7-8gb-512gb-ssd-freedos-14-fhd-tasinabilir-bilgisayar-82ka006xtx-p-HBCV00000DBWL5', 'https://www.hepsiburada.com/lenovo-ideapad-gaming-3-amd-ryzen-5-5600h-8gb-512gb-ssd-gtx1650-freedos-15-6-fhd-tasinabilir-bilgisayar-82k200k3tx-p-HBCV00000BDM1
intel-core-i7-1165g7-8gb-512gb-ssd-2gb-mx330-14-fhd-ubuntu-tasinabilir-bilgisayar-p-HBCV00000C7E0X', 'https://www.hepsiburada.com/casper-nirvana-c350-4000-4w00b-intel-celeron-n4000-4gb-120gb-ssd-windows-11-home-14-hd-tasinabilir-bilgisayar-p-HBCV000017FWLW', 'https://www.hepsiburada.com/hp-pavilion-15-dk207nt-intel-core-i5-11300h-8gb-512gb-ssd-rtx3050-freedos-15-6-tasinabilir-bilgisayar-54t32ea-p-HBCV00001XOSZ7']

# %%
len(products)
# Out:
# 2400

# %%
features = []
for product in products:
    html = getAndParseURL(product)
    try:
        brand = html.find("span",{"class":"brand-name"}).text.strip()
    except:
        brand = np.nan
    try:
        rating = html.find("span",{"class":"rating-star"}).text.strip().replace(",",".")
    except:
        rating = np.nan
    try:
        comment = html.find("div",{"id":"comments-container"}).span.text
    except:
        comment = np.nan
    try:
        seller_rating = html.find("span",{"class":"merchant-rating lv-5"}).text.strip()
    except:
        seller_rating = np.nan
    try:
        notebook_type = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Ürün Modeli")).findNext().text.strip()
    except:
        notebook_type = np.nan
    try:
        memory_speed = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Bellek Hızı")).findNext().text.strip()
    except:
        memory_speed = np.nan
    try:
        bluetooth = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Bluetooth Özelliği")).findNext().text.strip()
    except:
        bluetooth = np.nan
    try:
        weight = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Cihaz Ağırlığı")).findNext().text.strip()
    except:
        weight = np.nan
    try:
        touch_screen = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Dokunmatik Ekran")).findNext().text.strip()
    except:
        touch_screen = np.nan
    try:
        screen_size = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Ekran Boyutu")).findNext().text.strip()
    except:
        screen_size = np.nan
    try:
        gpu_type = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Ekran Kartı Tipi")).findNext().text.strip()
    except:
        gpu_type = np.nan
    try:
        gpu = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Ekran Kartı")).findNext().text.strip()
    except:
        gpu = np.nan
    try:
        cpu_gen = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("İşlemci Nesli")).findNext().text.strip()
    except:
        cpu_gen = np.nan
    try:
        cpu_type = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("İşlemci Tipi")).findNext().text.strip()
    except:
        cpu_type = np.nan
    try:
        os = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("İşletim Sistemi")).findNext().text.strip()
    except:
        os = np.nan
    try:
        max_cpu_speed = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Maksimum İşlemci Hızı")).findNext().text.strip().replace(",",".")
    except:
        max_cpu_speed = np.nan
    try:
        screen_resolution = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Max Ekran Çözünürlüğü")).findNext().text.strip()
    except:
        screen_resolution = np.nan
    try:
        finger_print = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Parmak İzi Okuyucu")).findNext().text.strip()
    except:
        finger_print = np.nan
    try:
        ram = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Ram")).findNext().text.strip()
    except:
        ram = np.nan
    try:
        ram_type = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Ram Tipi")).findNext().text.strip()
    except:
        ram_type = np.nan
    try:
        hdd = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Harddisk Kapasitesi")).findNext().text.strip()
    except:
        hdd = np.nan
    try:
        ssd = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("SSD Kapasitesi")).findNext().text.strip()
    except:
        ssd = np.nan
    try:
        charge_time = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Şarjlı Kullanım Süresi")).findNext().text.strip()
    except:
        charge_time = np.nan
    try:
        cpu_speed = html.find("table",{"class":"data-list tech-spec"}).find(text=re.compile("Temel İşlemci Hızı")).findNext().text.strip().replace(",",".")
    except:
        cpu_speed = np.nan
    try:
        price = html.find("span",{"data-bind":"markupText:'currentPriceBeforePoint'"}).text + " " + html.find("span",{"itemprop":"priceCurrency"}).text
    except:
        price = np.nan
        
    features.append([brand, rating, comment, seller_rating, notebook_type, memory_speed, bluetooth, weight,
                     touch_screen, screen_size, gpu_type, gpu, cpu_gen, cpu_type, os, max_cpu_speed,
                     screen_resolution, finger_print, ram, ram_type, hdd, ssd, charge_time, cpu_speed, price])
    time.sleep(1)
    
df_columns = ["Brand","Avg Rating","Total Comment","Seller Rating","Notebook Type","Memory Speed","Bluetooth","Weight",
             "Touch Screen","Screen Size","GPU Type","GPU","CPU Generation","CPU Type","OS","Max CPU Speed",
             "Screen Resolution","Finger Print","RAM","RAM Type","HDD","SSD","Charging Time","CPU Speed","Price"]

df = pd.DataFrame.from_records(features, columns=df_columns)

# %%
df
# Out:
#        Brand Avg Rating Total Comment Seller Rating        Notebook Type  \
# 0     Lenovo        4.7            15            10             Notebook
# 1     Lenovo        4.4           237           9,6             Notebook
# 2         HP        NaN           NaN            09             Notebook
# 3     Lenovo        NaN           NaN           9,1             Notebook
# 4     Casper        4.6            40            10  Oyun Bilgisayarları
# ...      ...        ...           ...           ...                  ...
# 2395   HONOR        4.8            48           9,1             Notebook
# 2396      HP        4.2            16           9,9             Notebook
# 2397    Asus        4.8           165           NaN             Notebook
# 2398    Dell        4.4             7           9,7             Notebook
# 2399  Casper        4.4           167           NaN             Notebook
#
#        Memory Speed Bluetooth        Weight   Touch Screen Screen Size  ...  \
# 0          3200 MHz       Var  2 kg ve Altı            Yok      14 inç  ...
# 1          2400 MHz       Var  2 kg ve Altı  Belirtilmemiş      14 inç  ...
# 2          3200 MHz       Var      1 - 2 kg            Yok      14 inç  ...
# 3          2933 MHz       Var      1 - 2 kg            Yok    15,6 inç  ...
# 4          2933 MHz       Var      2 - 4 kg            Yok    15,6 inç  ...
# ...             ...       ...           ...            ...         ...  ...
# 2395  Belirtilmemiş       Var      1 - 2 kg            Yok    15,6 inç  ...
# 2396       3200 MHz       Var      2 - 4 kg            Yok    15,6 inç  ...
# 2397       2400 MHz       Var      1 - 2 kg            Yok    15,6 inç  ...
# 2398       2666 MHz       Var      1 - 2 kg            Yok      14 inç  ...
# 2399       2133 MHz       Var      1 - 2 kg            Yok      14 inç  ...
#
#      Max CPU Speed Screen Resolution Finger Print    RAM RAM Type     HDD  \
# 0          4.2 GHz       1920 x 1080          Yok   8 GB     DDR4     Yok
# 1          2.8 GHz        1366 x 768          Yok   4 GB     DDR4     Yok
# 2          4.2 GHz       1920 x 1080          Yok   8 GB     DDR4     Yok
# 3          4.2 GHz       1920 x 1080          Yok  12 GB     DDR4     Yok
# 4          4.5 GHz       1920 x 1080          Yok   8 GB     DDR4     Yok
# ...            ...               ...          ...    ...      ...     ...
# 2395           Yok       1920 x 1080          Var   8 GB     DDR4  512 GB
# 2396       4.4 GHz       1920 x 1080          Yok  16 GB     DDR4     Yok
# 2397       4.1 GHz        1366 x 768          Yok   4 GB     DDR4     Yok
# 2398       4.7 GHz       1920 x 1080          Yok   8 GB     DDR4     Yok
# 2399       2.6 GHz        1366 x 768          Yok   4 GB     DDR3     Yok
#
#          SSD   Charging Time      CPU Speed      Price
# 0     512 GB  3 Saat ve Altı       2.40 GHz   8.999 TL
# 1     128 GB  6 Saat ve Üstü        1.1 GHz   3.820 TL
# 2     512 GB      4 - 6 Saat        2.4 GHz  14.088 TL
# 3       2 TB             NaN        2.4 GHz  16.139 TL
# 4     250 GB             NaN        2.5 GHz  12.499 TL
# ...      ...             ...            ...        ...
# 2395  512 GB             NaN  Belirtilmemiş   8.379 TL
# 2396  512 GB      4 - 6 Saat        2.6 GHz  15.999 TL
# 2397  256 GB             NaN        2.1 GHz   5.988 TL
# 2398  512 GB             NaN       2.80 GHz  16.399 TL
# 2399  120 GB             NaN       1.10 GHz   3.948 TL
#
# [2400 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              2400 non-null   object
#  1   Avg Rating         1575 non-null   object
#  2   Total Comment      1575 non-null   object
#  3   Seller Rating      2127 non-null   object
#  4   Notebook Type      2399 non-null   object
#  5   Memory Speed       2400 non-null   object
#  6   Bluetooth          2400 non-null   object
#  7   Weight             2400 non-null   object
#  8   Touch Screen       2400 non-null   object
#  9   Screen Size        2400 non-null   object
#  10  GPU Type           2400 non-null   object
#  11  GPU                2400 non-null   object
#  12  CPU Generation     2400 non-null   object
#  13  CPU Type           2400 non-null   object
#  14  OS                 2400 non-null   object
#  15  Max CPU Speed      2386 non-null   object
#  16  Screen Resolution  2399 non-null   object
#  17  Finger Print       2399 non-null   object
#  18  RAM                2399 non-null   object
#  19  RAM Type           2399 non-null   object
#  20  HDD                2400 non-null   object
#  21  SSD                2399 non-null   object
#  22  Charging Time      974 non-null    object
#  23  CPU Speed          2399 non-null   object
#  24  Price              2400 non-null   object
# dtypes: object(25)
# memory usage: 468.9+ KB

# %%
df["Memory Speed"] = df["Memory Speed"].str.extract("(\d+)") # Regular expression kullanarak istediğimiz ifadeye erişme

# %%
df["Memory Speed"]
# Out:
# 0       3200
# 1       2400
# 2       3200
# 3       2933
# 4       2933
#         ...
# 2395     NaN
# 2396    3200
# 2397    2400
# 2398    2666
# 2399    2133
# Name: Memory Speed, Length: 2400, dtype: object
